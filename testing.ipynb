# %%
stringie = "abhdef ghijk"
print(f"{"".join([letter for letter in reversed(stringie[::-1][0:(stringie.index("h") + 2)])])}")
print(stringie.__contains__("q"))
print("e" in stringie)
# Out:
# hijk
# False
# True

# %%
"wheeeeeeeeeee wheeeeeeeeeee"[::-1]
testie = "abcdefghijklm nopqrstuvwaxyz"
revtest = "".join([letter for letter in reversed(testie)])
testie.index("a")
# Out:
# 0

# %%
kList = ["d76aa478", "e8c7b756", "242070db", "c1bdceee",
         "f57c0faf", "4787c62a", "a8304613", "fd469501",
         "698098d8", "8b44f7af", "ffff5bb1", "895cd7be",
         "6b901122", "fd987193", "a679438e", "49b40821",
         "f61e2562", "c040b340", "265e5a51", "e9b6c7aa",
         "d62f105d", "02441453", "d8a1e681", "e7d3fbc8",
         "21e1cde6", "c33707d6", "f4d50d87", "455a14ed",
         "a9e3e905", "fcefa3f8", "676f02d9", "8d2a4c8a",
         "fffa3942", "8771f681", "6d9d6122", "fde5380c",
         "a4beea44", "4bdecfa9", "f6bb4b60", "bebfbc70",
         "289b7ec6", "eaa127fa", "d4ef3085", "04881d05",
         "d9d4d039", "e6db99e5", "1fa27cf8", "c4ac5665",
         "f4292244", "432aff97", "ab9423a7", "fc93a039",
         "655b59c3", "8f0ccc92", "ffeff47d", "85845dd1",
         "6fa87e4f", "fe2ce6e0", "a3014314", "4e0811a1",
         "f7537e82", "bd3af235", "2ad7d2bb", "eb86d391"]

# %%
def hexBin(hexString):
    dictie = {"0": "0000",
              "1": "0001",
              "2": "0010",
              "3": "0011",
              "4": "0100",
              "5": "0101",
              "6": "0110",
              "7": "0111",
              "8": "1000",
              "9": "1001",
              "a": "1010",
              "b": "1011",
              "c": "1100",
              "d": "1101",
              "e": "1110",
              "f": "1111"}
    result = ""
    for char in hexString:
        result += dictie[char]
    return result

# %%
[[hexBin(kval.strip()) for kval in line.split(",")[:-1]] for line in open("./Hash/shiftrot", "r").read().split("\n")][:16]
# Out:
# [['11010111011010101010010001111000',
#   '11101000110001111011011101010110',
#   '00100100001000000111000011011011',
#   '11000001101111011100111011101110'],
#  ['11110101011111000000111110101111',
#   '01000111100001111100011000101010',
#   '10101000001100000100011000010011',
#   '11111101010001101001010100000001'],
#  ['01101001100000001001100011011000',
#   '10001011010001001111011110101111',
#   '11111111111111110101101110110001',
#   '10001001010111001101011110111110'],
#  ['01101011100100000001000100100010',
#   '11111101100110000111000110010011',
#   '10100110011110010100001110001110',
#   '01001001101101000000100000100001'],
#  ['11110110000111100010010101100010',
#   '11000000010000001011001101000000',
#   '00100110010111100101101001010001',
#   '11101001101101101100011110101010'],
#  ['11010110001011110001000001011101',
#   '00000010010001000001010001010011',
#   '11011000101000011110011010000001',
#   '11100111110100111111101111001000'],
# ...

# %%
[[kval.strip() for kval in line.split(",")[:-1]] for line in open("./Hash/shiftrot", "r").read().split("\n")][:16]
# Out:
# [['d76aa478', 'e8c7b756', '242070db', 'c1bdceee'],
#  ['f57c0faf', '4787c62a', 'a8304613', 'fd469501'],
#  ['698098d8', '8b44f7af', 'ffff5bb1', '895cd7be'],
#  ['6b901122', 'fd987193', 'a679438e', '49b40821'],
#  ['f61e2562', 'c040b340', '265e5a51', 'e9b6c7aa'],
#  ['d62f105d', '02441453', 'd8a1e681', 'e7d3fbc8'],
#  ['21e1cde6', 'c33707d6', 'f4d50d87', '455a14ed'],
#  ['a9e3e905', 'fcefa3f8', '676f02d9', '8d2a4c8a'],
#  ['fffa3942', '8771f681', '6d9d6122', 'fde5380c'],
#  ['a4beea44', '4bdecfa9', 'f6bb4b60', 'bebfbc70'],
#  ['289b7ec6', 'eaa127fa', 'd4ef3085', '04881d05'],
#  ['d9d4d039', 'e6db99e5', '1fa27cf8', 'c4ac5665'],
#  ['f4292244', '432aff97', 'ab9423a7', 'fc93a039'],
#  ['655b59c3', '8f0ccc92', 'ffeff47d', '85845dd1'],
#  ['6fa87e4f', 'fe2ce6e0', 'a3014314', '4e0811a1'],
#  ['f7537e82', 'bd3af235', '2ad7d2bb', 'eb86d391']]

# %%
def prettyPrint(text):
    returned = ""
    for i in range(len(text)):
        if (i % 64 == 0):
            returned += "\n"
        if (i % 8 == 0):
            returned += " "
        returned += text[i]
    return returned[1:]


print(prettyPrint("..."))
# Out:
#  10100000 00000000 00000000 00000000 00000000 00000000 00000000 00000000
#  00000000 00000000 00000000 00000000 00000000 00000000 00000000 00000000
#  00000000 00000000 00000000 00000000 00000000 00000000 00000000 00000000
#  00000000 00000000 00000000 00000000 00000000 00000000 00000000 00000000
#  00000000 00000000 00000000 00000000 00000000 00000000 00000000 00000000
#  00000000 00000000 00000000 00000000 00000000 00000000 00000000 00000000
#  00000000 00000000 00000000 00000000 00000000 00000000 00000000 00000000
#  10000000 00000000 00000000 00000000 00000000 00000000 00000000 00000000

# %%
tuppie = (1, 2, 3, 4)
(*tuppie[:4], 1)
# Out:
# (1, 2, 3, 4, 1)

# %%
import Caesar.caesar
